# %%
import cv2

print('version OpenCV', cv2.__version__)
# Out:
# version OpenCV 4.9.0

# %%
img1 = cv2.imread('Images/122177016_1596240143870672_8491193916115244868_n.jpg')

print(img1)
# Out:
# [[[219 216 218]
#   [219 216 218]
#   [219 216 218]
#   ...
#   [217 217 217]
#   [217 217 217]
#   [217 217 217]]
#
#  [[219 216 218]
#   [219 216 218]
#   [219 216 218]
#   ...
#   [217 217 217]
#   [217 217 217]
#   [217 217 217]]
#
#  [[219 216 218]
#   [219 216 218]
#   [219 216 218]
#   ...
#   [217 217 217]
#   [217 217 217]
#   [217 217 217]]
#
#  ...
#
#  [[ 99 108 118]
#   [ 98 107 117]
#   [ 98 106 119]
#   ...
#   [ 36  38  62]
#   [ 37  39  63]
#   [ 34  36  60]]
#
#  [[ 98 106 119]
#   [ 98 106 119]
#   [ 98 106 119]
#   ...
#   [ 39  40  66]
#   [ 40  41  67]
#   [ 36  37  63]]
#
#  [[ 97 105 118]
#   [ 97 105 118]
#   [ 97 105 118]
#   ...
#   [ 42  43  69]
#   [ 44  45  71]
#   [ 38  39  65]]]

# %%
import matplotlib.pyplot as plt 

plt.imshow(img1,cmap='grey')

plt.grid(ls='--')
plt.show()

# %%
import numpy as np

# %%
#Đọc và hiển thị nhiều hình ảnh 

pic1 = cv2.imread('Images/440746060_878369394305599_3538830233656657343_n.jpg',1) #Đường dẫn file ảnh

plt.figure(figsize=(10,8))
#Hiển thị ảnh 
plt.imshow(pic1,cmap='Blues')
plt.show()

# %%
#Đọc và hiển thị nhiều hình ảnh 

pic2 = cv2.imread('Images/123775259_358878288510300_8756619496107720415_n.jpg',0) #Đường dẫn file ảnh

plt.figure(figsize=(10,8))
#Hiển thị ảnh 
plt.imshow(pic2,cmap='Blues')
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.subplot(1,3,1)
plt.imshow(pic1,cmap='gray')

plt.subplot(1,3,2)
plt.imshow(pic2,cmap='gray')

plt.subplot(1,3,3)
plt.imshow(img1,cmap='gray')

plt.show()
